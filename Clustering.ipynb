# %% [markdown]
# <a href="https://colab.research.google.com/github/eakanshagarwal/eakansh-demo/blob/main/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
from pycaret.clustering import *
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
result_df = pd.DataFrame()

# %%
data_df = pd.read_csv("/content/NPHA-doctor-visits.csv")

# %%
data_df.head(10)
# Out:
#    Number of Doctors Visited  Age  Phyiscal Health  Mental Health  \
# 0                          3    2                4              3
# 1                          2    2                4              2
# 2                          3    2                3              2
# 3                          1    2                3              2
# 4                          3    2                3              3
# 5                          2    2                3              2
# 6                          3    2                4              1
# 7                          2    2                3              2
# 8                          2    2                3              1
# 9                          1    2                2              1
#
#    Dental Health  Employment  Stress Keeps Patient from Sleeping  \
# 0              3           3                                   0
# 1              3           3                                   1
# ...

# %% [markdown]
# ### **Clustering -(Kmean Clustering)**

# %%
from pycaret.clustering import *

setup(data = data_df, verbose=False)

print("For Cluster = 3")
x1 = create_model('kmeans', num_clusters = 3)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_be926" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be926_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_be926_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_be926_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_be926_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_be926_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_be926_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be926_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be926_row0_col0" class="data row0 col0" >0.2066</td>
#       <td id="T_be926_row0_col1" class="data row0 col1" >153.8282</td>
# ...

# %% [markdown]
#  Ploting the Cluster
#
# ```
# - Cluster PCA Plot (2d)          'cluster'
# - Cluster TSnE (3d)              'tsne'
# - Elbow Plot                     'elbow'
# - Silhouette Plot                'silhouette'
# - Distance Plot                  'distance'
# - Distribution Plot              'distribution'
# ```

# %%
evaluate_model(x1)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(x1, plot='cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(x1, plot='tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(x1, plot='elbow')

# %%
plot_model(x1, plot='silhouette')

# %%
plot_model(x1, plot='distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#No Data Processing

from pycaret.clustering import *

setup(data = data_df, verbose=False)

print("For Cluster = 3")
x1 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_7a3f1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a3f1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7a3f1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7a3f1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7a3f1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7a3f1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7a3f1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a3f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a3f1_row0_col0" class="data row0 col0" >0.2066</td>
#       <td id="T_7a3f1_row0_col1" class="data row0 col1" >153.8282</td>
# ...

# %%
#Normalization

from pycaret.clustering import *

setup(data = data_df, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x1 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_b5a06" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5a06_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b5a06_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b5a06_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b5a06_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b5a06_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b5a06_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5a06_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5a06_row0_col0" class="data row0 col0" >0.0979</td>
#       <td id="T_b5a06_row0_col1" class="data row0 col1" >75.4726</td>
# ...

# %%
#Using Transform

from pycaret.clustering import *

setup(data = data_df, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_1a22c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a22c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1a22c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1a22c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1a22c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1a22c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1a22c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a22c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a22c_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_1a22c_row0_col1" class="data row0 col1" >77421302193245.4688</td>
# ...

# %%
#Using PCA

setup(data = data_df,pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_fed8f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fed8f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fed8f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fed8f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fed8f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fed8f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fed8f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fed8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fed8f_row0_col0" class="data row0 col0" >0.2066</td>
#       <td id="T_fed8f_row0_col1" class="data row0 col1" >153.8282</td>
# ...

# %%
#Using Transform + Normalization

setup(data = data_df, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_6f3d4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f3d4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6f3d4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6f3d4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6f3d4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6f3d4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6f3d4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f3d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f3d4_row0_col0" class="data row0 col0" >0.0979</td>
#       <td id="T_6f3d4_row0_col1" class="data row0 col1" >75.4802</td>
# ...

# %%
#Using Trnasform + Normalization + PCA

setup(data = data_df, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_af0ab" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af0ab_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_af0ab_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_af0ab_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_af0ab_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_af0ab_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_af0ab_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af0ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af0ab_row0_col0" class="data row0 col0" >0.0960</td>
#       <td id="T_af0ab_row0_col1" class="data row0 col1" >75.6917</td>
# ...

# %% [markdown]
# ### **Clustering -(Affinity Propagation )**

# %%
#No Data Processing

from pycaret.clustering import *

setup(data = data_df, verbose=False)

print("For Cluster = 3")
x1 = create_model('ap', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('ap', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('ap', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_4bb5a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bb5a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4bb5a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4bb5a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4bb5a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4bb5a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4bb5a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bb5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4bb5a_row0_col0" class="data row0 col0" >0.0790</td>
#       <td id="T_4bb5a_row0_col1" class="data row0 col1" >24.8047</td>
# ...

# %%
#Using Normalization
setup(data = data_df, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x1 = create_model('ap', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('ap', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('ap', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_69dae" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69dae_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_69dae_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_69dae_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_69dae_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_69dae_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_69dae_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69dae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69dae_row0_col0" class="data row0 col0" >0.1200</td>
#       <td id="T_69dae_row0_col1" class="data row0 col1" >21.2982</td>
# ...

# %%
#Using Transform

setup(data = data_df, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('ap', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('ap', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('ap', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_f16f4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f16f4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f16f4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f16f4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f16f4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f16f4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f16f4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f16f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f16f4_row0_col0" class="data row0 col0" >0.4288</td>
#       <td id="T_f16f4_row0_col1" class="data row0 col1" >115697268898702624.0000</td>
# ...

# %%
#Using PCA

setup(data = data_df,pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('ap', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('ap', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('ap', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_b62e3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b62e3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b62e3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b62e3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b62e3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b62e3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b62e3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b62e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b62e3_row0_col0" class="data row0 col0" >0.0838</td>
#       <td id="T_b62e3_row0_col1" class="data row0 col1" >24.6159</td>
# ...

# %%
#Using Transform + Normalization

setup(data = data_df, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('ap', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('ap', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('ap', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_05220" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05220_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_05220_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_05220_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_05220_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_05220_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_05220_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05220_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05220_row0_col0" class="data row0 col0" >0.1202</td>
#       <td id="T_05220_row0_col1" class="data row0 col1" >21.2961</td>
# ...

# %%
#Using Trnasform + Normalization + PCA

setup(data = data_df, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('ap', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('ap', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('ap', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_86ea0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86ea0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_86ea0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_86ea0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_86ea0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_86ea0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_86ea0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86ea0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86ea0_row0_col0" class="data row0 col0" >0.1361</td>
#       <td id="T_86ea0_row0_col1" class="data row0 col1" >20.9309</td>
# ...

# %% [markdown]
# ### **Clustering -(Mean shift clustering )**

# %%
print("No Data Processing")

from pycaret.clustering import *

setup(data = data_df, verbose=False)

print("For Cluster = 3")
x1 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('meanshift', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Normalization")
setup(data = data_df, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x1 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('meanshift', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Transform")

setup(data = data_df, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('meanshift', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using PCA")

setup(data = data_df,pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('meanshift', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Transform + Normalization")

setup(data = data_df, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('meanshift', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Trnasform + Normalization + PCA")

setup(data = data_df, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('meanshift', num_clusters = 5)
# Out:
# No Data Processing
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_90a50" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90a50_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_90a50_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_90a50_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_90a50_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_90a50_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_90a50_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90a50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90a50_row0_col0" class="data row0 col0" >0.1808</td>
#       <td id="T_90a50_row0_col1" class="data row0 col1" >15.0202</td>
# ...

# %% [markdown]
# ### **Clustering -(Spectral clustering )**

# %%
print("No Data Processing")

from pycaret.clustering import *

setup(data = data_df, verbose=False)

print("For Cluster = 3")
x1 = create_model('sc', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('sc', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('sc', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Normalization")
setup(data = data_df, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x1 = create_model('sc', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('sc', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('sc', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Transform")

setup(data = data_df, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('sc', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('sc', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('sc', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using PCA")

setup(data = data_df,pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('sc', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('sc', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('sc', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Transform + Normalization")

setup(data = data_df, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('sc', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('sc', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('sc', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Trnasform + Normalization + PCA")

setup(data = data_df, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('sc', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('sc', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('sc', num_clusters = 5)
# Out:
# No Data Processing
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_02a41" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02a41_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_02a41_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_02a41_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_02a41_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_02a41_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_02a41_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02a41_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02a41_row0_col0" class="data row0 col0" >0.2411</td>
#       <td id="T_02a41_row0_col1" class="data row0 col1" >109.0303</td>
# ...

# %% [markdown]
# ### **Clustering -(Agglomerative Clustering )**

# %%
print("No Data Processing")

from pycaret.clustering import *

setup(data = data_df, verbose=False)

print("For Cluster = 3")
x1 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('hclust', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Normalization")
setup(data = data_df, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x1 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('hclust', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Transform")

setup(data = data_df, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('hclust', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using PCA")

setup(data = data_df,pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('hclust', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Transform + Normalization")

setup(data = data_df, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('hclust', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Trnasform + Normalization + PCA")

setup(data = data_df, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('hclust', num_clusters = 5)
# Out:
# No Data Processing
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_ae85f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae85f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ae85f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ae85f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ae85f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ae85f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ae85f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae85f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae85f_row0_col0" class="data row0 col0" >0.1164</td>
#       <td id="T_ae85f_row0_col1" class="data row0 col1" >109.7942</td>
# ...

# %% [markdown]
# ### **Clustering -(Birch Clustering )**

# %%
print("No Data Processing")

from pycaret.clustering import *

setup(data = data_df, verbose=False)

print("For Cluster = 3")
x1 = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('birch', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Normalization")
setup(data = data_df, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x1 = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('birch', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Transform")

setup(data = data_df, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('birch', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using PCA")

setup(data = data_df,pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('birch', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Transform + Normalization")

setup(data = data_df, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x1 = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('birch', num_clusters = 5)

print(" ")
print(" ")
print(" ")
print(" ")
print("Using Trnasform + Normalization + PCA")

setup(data = data_df, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x1 = create_model('birch', num_clusters = 3)

print("For Cluster = 4")
x2 = create_model('birch', num_clusters = 4)

print("For Cluster = 5")
x3 = create_model('birch', num_clusters = 5)
# Out:
# No Data Processing
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_c9b22" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9b22_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c9b22_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c9b22_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c9b22_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c9b22_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c9b22_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9b22_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9b22_row0_col0" class="data row0 col0" >0.1970</td>
#       <td id="T_c9b22_row0_col1" class="data row0 col1" >129.9404</td>
# ...
